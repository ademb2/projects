# %%
from bs4 import BeautifulSoup
import requests

# %%
url="https://animaldiversity.org/accounts/Panthera_tigris/"
html_content = requests.get(url)
soup = BeautifulSoup(html_content.content, 'html.parser')
print(soup)
column = soup.find_all('h3', id='habitat')
information = soup.find('li', class_='keywords-header')
#sub = information.find('a', class_='gloss').text
column
#information
#sub
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xml:lang="en" xmlns:og="http://ogp.me/ns#">
# <head>
# <title>ADW: Panthera tigris: INFORMATION</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="https://animaldiversity.org/accounts/Panthera_tigris/" rel="canonical"/>
# <script src="//code.jquery.com/jquery-3.6.0.min.js" type="text/javascript"></script>
# <script src="//code.jquery.com/jquery-migrate-3.3.2.min.js" type="text/javascript"></script>
# <script src="/static/js/compat.js" type="text/javascript"></script>
# <link href="https://animaldiversity.org/favicon.ico" rel="shortcut icon"/>
# <link href="//fonts.googleapis.com/css?family=Gentium+Book+Basic:400,400italic,700,700italic" rel="stylesheet" type="text/css"/>
# <link href="//fonts.googleapis.com/css?family=PT+Sans:400,700,400italic,700italic" rel="stylesheet" type="text/css"/>
# <link href="/static/bootstrap/css/bootstrap.css" rel="stylesheet" type="text/css"/>
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Replace with the actual website URL
url="https://animaldiversity.org/accounts/Panthera_tigris/"

# Retrieve the HTML content
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# Find all h3 elements with id="habitat"
habitat_headers = soup.find_all("h3", id="habitat")

for habitat_header in habitat_headers:
  # Extract habitat text
  habitat_text = habitat_header.text.strip()

  # Find all ul elements directly following the habitat header
  ul_elements = habitat_header.find_next_siblings("ul")

  # Loop through each ul element (assuming multiple might exist)
  for ul_element in ul_elements:
    # Lists to store keywords and gloss data
    keywords = []
    gloss_texts = []

    # Loop through keywords-header elements within the current ul
    for keyword_element in ul_element.find_all("li", class_="keywords-header"):
      keywords.append(keyword_element.text.strip())

    # Loop through gloss elements within the current ul
    for gloss_link in ul_element.find_all("a", class_="gloss"):
      gloss_texts.append(gloss_link.text.strip())

    # Loop through span elements within the current ul
    for span_element in ul_element.find_all("span"):
      gloss_texts.append(span_element.text.strip())

    # Print scraped data for each habitat and its associated data
    print("Habitat Text:", habitat_text)
    print("Keywords:", keywords)
    print("Gloss Texts:", gloss_texts)
    
    print("-" * 30)  # Optional separator between sections

# Find all h3 elements with id="food_habits"
food_habit_headers = soup.find_all("h3", id="food_habits")

for food_habit_header in food_habit_headers:
  # Extract food habit text
  food_habit_text = food_habit_header.text.strip()

  # Find all ul elements directly following the food habit header
  ul_elements = food_habit_header.find_next_siblings("ul")

  # Loop through each ul element (assuming multiple might exist)
  for ul_element in ul_elements:
    # Lists to store keywords and gloss data
    keywords = []
    gloss_texts = []

    # Loop through keywords-header elements within the current ul
    for keyword_element in ul_element.find_all("li", class_="keywords-header"):
      keywords.append(keyword_element.text.strip())

    # Loop through gloss elements within the current ul
    for gloss_link in ul_element.find_all("a", class_="gloss"):
      gloss_texts.append(gloss_link.text.strip())

    # Loop through span elements within the current ul
    for span_element in ul_element.find_all("span"):
      gloss_texts.append(span_element.text.strip())

    # Print scraped data for each food habit and its associated data
    print("Food Habit Text:", food_habit_text)
    print("Keywords:", keywords)
    print("Gloss Texts:", gloss_texts)
    
    print("-" * 30)  # Optional separator between sections
# Out:
# Habitat Text: Habitat
# Keywords: ['Habitat Regions']
# Gloss Texts: ['temperate', 'tropical', 'terrestrial']
# ------------------------------
# Habitat Text: Habitat
# Keywords: ['Terrestrial Biomes']
# Gloss Texts: ['tundra', 'taiga', 'savanna or grassland', 'forest', 'rainforest', 'scrub forest', 'mountains']
# ------------------------------
# Habitat Text: Habitat
# Keywords: ['Wetlands']
# Gloss Texts: ['marsh']
# ------------------------------
# Food Habit Text: Food Habits
# Keywords: ['Primary Diet']
# Gloss Texts: ['carnivore', 'eats terrestrial vertebrates']
# ------------------------------
# Food Habit Text: Food Habits
# Keywords: ['Animal Foods']
# Gloss Texts: ['birds', 'mammals', 'reptiles', 'fish']
# ------------------------------
# Food Habit Text: Food Habits
# Keywords: ['Foraging Behavior']
# Gloss Texts: ['stores or caches food']
# ------------------------------

# %%
import requests
from bs4 import BeautifulSoup

species_names=("Loxodonta africana", "Ovis aries", "Bos taurus", "Alces alces", "Antilocapra americana", "Bison bison", "Odocoileus virginianus", "Oreamnos americanus", "Ovibos moschatus", "Ovis canadensis", "Dasypus novemcinctus", "Cervus canadensis", "Rangifer tarandus", "Antrozous pallidus", "Lasiurus blossevillii", "Leptonycteris curasoae", "Propithecus verreauxi", "Callithrix jacchus", "Daubentonia madagascariensis", "Sorex arcticus", "Enhydra lutris", "Lama glama", "Lama guanicoe", "Vicugna vicugna", "Vicugna pacos", "Homo sapiens", "Tarsius syrichta", "Mephitis mephitis", "Mustela spp.", "Taxidea taxus", "Neovison vison", "Lemur catta", "Galago senegalensis", "Nycticebus coucang", "Sapajus spp.", "Tayassuidae spp.", "Martes spp.", "Procyon lotor", "Nasua nasua", "Equus caballus", "Sus scrofa", "Sus scrofa", "Didelphis virginiana", "Mus musculus", "Ondatra zibethicus", "Oryzomys palustris", "Zapus hudsonius", "Castor canadensis", "Dipodomys ingens", "Erethizon dorsatum", "Geomys spp.", "Myocastor coypus", "Sciurus apache", "Aplodontia rufa", "Sciurus granatensis", "Tamias spp.", "Tamiasciurus hudsonicus", "Cynomys ludovicianus", "Marmota monax", "Ochotona princeps", "Oryctolagus cuniculus", "Lepus europaeus", "Lynx canadensis", "Panthera onca", "Felis catus", "Panthera leo", "Leopardus pardalis", "Vulpes lagopus", "Urocyon cinereoargenteus", "Canis latrans", "Ursus arctos", "Ursus maritimus", "Ursus arctos horribilis", "Ursus americanus", "Canis lupus", "Canis lupus familiaris")

urls = []  # List to store the formatted URLs

for species_name in species_names:
    # Format the URL with the species name
    url = f"https://animaldiversity.org/accounts/{species_name}"
    urls.append(url)

    # Retrieve the HTML content
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Find all h3 elements with id="habitat"
    habitat_headers = soup.find_all("h3", id="habitat")

    for habitat_header in habitat_headers:
        # Extract habitat text
        habitat_text = habitat_header.text.strip()

        # Find all ul elements directly following the habitat header
        ul_elements = habitat_header.find_next_siblings("ul")

        # Loop through each ul element (assuming multiple might exist)
        for ul_element in ul_elements:
            # Lists to store keywords and gloss data
            keywords = []
            gloss_texts = []

            # Loop through keywords-header elements within the current ul
            for keyword_element in ul_element.find_all("li", class_="keywords-header"):
                keywords.append(keyword_element.text.strip())

            # Loop through gloss elements within the current ul
            for gloss_link in ul_element.find_all("a", class_="gloss"):
                gloss_texts.append(gloss_link.text.strip())

            # Loop through span elements within the current ul
            for span_element in ul_element.find_all("span"):
                gloss_texts.append(span_element.text.strip())

            # Print scraped data for each habitat and its associated data
            print("Habitat Text:", habitat_text)
            print("Keywords:", keywords)
            print("Gloss Texts:", gloss_texts)
            
            print("-" * 30)  # Optional separator between sections

    # Find all h3 elements with id="food_habits"
    food_habit_headers = soup.find_all("h3", id="food_habits")

    for food_habit_header in food_habit_headers:
        # Extract food habit text
        food_habit_text = food_habit_header.text.strip()

        # Find all ul elements directly following the food habit header
        ul_elements = food_habit_header.find_next_siblings("ul")

        # Loop through each ul element (assuming multiple might exist)
        for ul_element in ul_elements:
            # Lists to store keywords and gloss data
            keywords = []
            gloss_texts = []

            # Loop through keywords-header elements within the current ul
            for keyword_element in ul_element.find_all("li", class_="keywords-header"):
                keywords.append(keyword_element.text.strip())

            # Loop through gloss elements within the current ul
            for gloss_link in ul_element.find_all("a", class_="gloss"):
                gloss_texts.append(gloss_link.text.strip())

            # Loop through span elements within the current ul
            for span_element in ul_element.find_all("span"):
                gloss_texts.append(span_element.text.strip())

            # Print scraped data for each food habit and its associated data
            print("Food Habit Text:", food_habit_text)
            print("Keywords:", keywords)
            print("Gloss Texts:", gloss_texts)
            
            print("-" * 30)  # Optional separator between sections

    # Optional separator between species
    #print("-" * 30)
for species_name in species_names:
    # Format the URL with the species name
    url = f"https://animaldiversity.org/accounts/{species_name}"
    urls.append(url)

    # Retrieve the HTML content
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Find all h3 elements with id="habitat"
    habitat_headers = soup.find_all("h3", id="habitat")

    for habitat_header in habitat_headers:
        # Extract habitat text
        habitat_text = habitat_header.text.strip()

        # Find all ul elements directly following the habitat header
        ul_elements = habitat_header.find_next_siblings("ul")

        # Loop through each ul element (assuming multiple might exist)
        for ul_element in ul_elements:
            # Lists to store keywords and gloss data
            keywords = []
            gloss_texts = []

            # Loop through keywords-header elements within the current ul
            for keyword_element in ul_element.find_all("li", class_="keywords-header"):
                keywords.append(keyword_element.text.strip())

            # Loop through gloss elements within the current ul
            for gloss_link in ul_element.find_all("a", class_="gloss"):
                gloss_texts.append(gloss_link.text.strip())

            # Loop through span elements within the current ul
            for span_element in ul_element.find_all("span"):
                gloss_texts.append(span_element.text.strip())

            # Print scraped data for each habitat and its associated data
            print(f"Species Name: {species_name}")
            print("Habitat Text:", habitat_text)
            print("Keywords:", keywords)
            print("Gloss Texts:", gloss_texts)
            
            print("-" * 30)  # Optional separator between sections

    # Find all h3 elements with id="food_habits"
    food_habit_headers = soup.find_all("h3", id="food_habits")

    for food_habit_header in food_habit_headers:
        # Extract food habit text
        food_habit_text = food_habit_header.text.strip()

        # Find all ul elements directly following the food habit header
        ul_elements = food_habit_header.find_next_siblings("ul")

        # Loop through each ul element (assuming multiple might exist)
        for ul_element in ul_elements:
            # Lists to store keywords and gloss data
            keywords = []
            gloss_texts = []

            # Loop through keywords-header elements within the current ul
            for keyword_element in ul_element.find_all("li", class_="keywords-header"):
                keywords.append(keyword_element.text.strip())

            # Loop through gloss elements within the current ul
            for gloss_link in ul_element.find_all("a", class_="gloss"):
                gloss_texts.append(gloss_link.text.strip())

            # Loop through span elements within the current ul
            for span_element in ul_element.find_all("span"):
                gloss_texts.append(span_element.text.strip())

            # Print scraped data for each food habit and its associated data
            print(f"Species Name: {species_name}")
            print("Food Habit Text:", food_habit_text)
            print("Keywords:", keywords)
            print("Gloss Texts:", gloss_texts)
            
            print("-" * 30)  # Optional separator between sections
# Out:
# Habitat Text: Habitat
# Keywords: ['Habitat Regions']
# Gloss Texts: ['tropical', 'terrestrial']
# ------------------------------
# Habitat Text: Habitat
# Keywords: ['Terrestrial Biomes']
# Gloss Texts: ['desert or dune', 'savanna or grassland', 'rainforest', 'scrub forest']
# ------------------------------
# Habitat Text: Habitat
# Keywords: []
# Gloss Texts: []
# ------------------------------
# Food Habit Text: Food Habits
# Keywords: ['Primary Diet']
# Gloss Texts: ['herbivore', 'folivore', 'frugivore', 'lignivore']
# ------------------------------
# Food Habit Text: Food Habits
# Keywords: ['Plant Foods']
# Gloss Texts: ['leaves', 'roots and tubers', 'wood, bark, or stems', 'fruit']
# ------------------------------
# Habitat Text: Habitat
# Keywords: ['Terrestrial Biomes']
# Gloss Texts: ['desert or dune', 'savanna or grassland', 'chaparral', 'forest', 'scrub forest', 'mountains']
# ------------------------------
# Habitat Text: Habitat
# Keywords: ['Habitat Regions']
# ...

# %%
import pandas as pd
for species_name in species_names:
    # Format the URL with the species name
    url = f"https://animaldiversity.org/accounts/{species_name}"
    urls.append(url)

    # Retrieve the HTML content
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Find all h3 elements with id="habitat"
    habitat_headers = soup.find_all("h3", id="habitat")

    for habitat_header in habitat_headers:
        # Extract habitat text
        habitat_text = habitat_header.text.strip()

        # Find all ul elements directly following the habitat header
        ul_elements = habitat_header.find_next_siblings("ul")

        # Loop through each ul element (assuming multiple might exist)
        for ul_element in ul_elements:
            # Lists to store keywords and gloss data
            keywords = []
            gloss_texts = []

            # Loop through keywords-header elements within the current ul
            for keyword_element in ul_element.find_all("li", class_="keywords-header"):
                keywords.append(keyword_element.text.strip())

            # Loop through gloss elements within the current ul
            for gloss_link in ul_element.find_all("a", class_="gloss"):
                gloss_texts.append(gloss_link.text.strip())

            # Loop through span elements within the current ul
            for span_element in ul_element.find_all("span"):
                gloss_texts.append(span_element.text.strip())

            # Print scraped data for each habitat and its associated data
            print(f"Species Name: {species_name}")
            print("Habitat Text:", habitat_text)
            print("Keywords:", keywords)
            print("Gloss Texts:", gloss_texts)
            
            print("-" * 30)  # Optional separator between sections

    # Find all h3 elements with id="food_habits"
    food_habit_headers = soup.find_all("h3", id="food_habits")

    for food_habit_header in food_habit_headers:
        # Extract food habit text
        food_habit_text = food_habit_header.text.strip()

        # Find all ul elements directly following the food habit header
        ul_elements = food_habit_header.find_next_siblings("ul")

        # Loop through each ul element (assuming multiple might exist)
        for ul_element in ul_elements:
            # Lists to store keywords and gloss data
            keywords = []
            gloss_texts = []

            # Loop through keywords-header elements within the current ul
            for keyword_element in ul_element.find_all("li", class_="keywords-header"):
                keywords.append(keyword_element.text.strip())

            # Loop through gloss elements within the current ul
            for gloss_link in ul_element.find_all("a", class_="gloss"):
                gloss_texts.append(gloss_link.text.strip())

            # Loop through span elements within the current ul
            for span_element in ul_element.find_all("span"):
                gloss_texts.append(span_element.text.strip())

            # Print scraped data for each food habit and its associated data
            print(f"Species Name: {species_name}")
            print("Food Habit Text:", food_habit_text)
            print("Keywords:", keywords)
            print("Gloss Texts:", gloss_texts)
            
            print("-" * 30)  # Optional separator between sections
# Out:
# Species Name: Loxodonta africana
# Habitat Text: Habitat
# Keywords: ['Habitat Regions']
# Gloss Texts: ['tropical', 'terrestrial']
# ------------------------------
# Species Name: Loxodonta africana
# Habitat Text: Habitat
# Keywords: ['Terrestrial Biomes']
# Gloss Texts: ['desert or dune', 'savanna or grassland', 'rainforest', 'scrub forest']
# ------------------------------
# Species Name: Loxodonta africana
# Habitat Text: Habitat
# Keywords: []
# Gloss Texts: []
# ------------------------------
# Species Name: Loxodonta africana
# Food Habit Text: Food Habits
# Keywords: ['Primary Diet']
# Gloss Texts: ['herbivore', 'folivore', 'frugivore', 'lignivore']
# ------------------------------
# Species Name: Loxodonta africana
# Food Habit Text: Food Habits
# Keywords: ['Plant Foods']
# Gloss Texts: ['leaves', 'roots and tubers', 'wood, bark, or stems', 'fruit']
# ------------------------------
# Species Name: Ovis aries
# Habitat Text: Habitat
# Keywords: ['Terrestrial Biomes']
# ...

# %%
#functionnal but not complete
#dont touh it, experiment with the following cell

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Initialize a list to store data dictionaries for each species
data_list = []

# Assuming 'species_names' is a list of species names
for species_name in species_names:
    # Format the URL with the species name
    url = f"https://animaldiversity.org/accounts/{species_name}"

    # Retrieve the HTML content
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    # Find all h3 elements with id="habitat"
    habitat_headers = soup.find_all("h3", id="habitat")

    for habitat_header in habitat_headers:
        # Extract habitat text
        habitat_text = habitat_header.text.strip()

        # Find all ul elements directly following the habitat header
        ul_elements = habitat_header.find_next_siblings("ul")

        # Loop through each ul element (assuming multiple might exist)
        for ul_element in ul_elements:
            # Lists to store keywords and gloss data
            keywords = []
            gloss_texts = []

            # Loop through keywords-header elements within the current ul
            for keyword_element in ul_element.find_all("li", class_="keywords-header"):
                keywords.append(keyword_element.text.strip())

            # Loop through gloss elements within the current ul
            for gloss_link in ul_element.find_all("a", class_="gloss"):
                gloss_texts.append(gloss_link.text.strip())

            # Loop through span elements within the current ul
            for span_element in ul_element.find_all("span"):
                gloss_texts.append(span_element.text.strip())

            # Convert gloss_texts to a string representation
            gloss_texts_str = ', '.join(gloss_texts)

            # Create a dictionary for the current species and habitat
            species_data = {'Species Name': species_name, 'Habitat': habitat_text}

            # Add keywords and gloss texts to the dictionary
            for k in keywords:
                species_data[k] = gloss_texts_str

            # Append the data dictionary for the current species to the list
            data_list.append(species_data)

# Create a DataFrame from the collected data
df = pd.DataFrame(data_list)
df
# Out:
#                Species Name  Habitat                          Habitat Regions  \
# 0        Loxodonta africana  Habitat                    tropical, terrestrial
# 1        Loxodonta africana  Habitat                                      NaN
# 2        Loxodonta africana  Habitat                                      NaN
# 3                Ovis aries  Habitat                                      NaN
# 4                Bos taurus  Habitat         temperate, tropical, terrestrial
# ..                      ...      ...                                      ...
# 197             Canis lupus  Habitat                   temperate, terrestrial
# 198             Canis lupus  Habitat                                      NaN
# 199  Canis lupus familiaris  Habitat  temperate, tropical, polar, terrestrial
# 200  Canis lupus familiaris  Habitat                                      NaN
# 201  Canis lupus familiaris  Habitat                                      NaN
#
# ...

# %%
## experiment

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Initialize a list to store data dictionaries for each species
data_list = []

# Assuming 'species_names' is a list of species names
for species_name in species_names:
    # Format the URL with the species name
    url = f"https://animaldiversity.org/accounts/{species_name}"

    # Retrieve the HTML content
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    # Find all h3 elements with id="habitat"
    habitat_headers = soup.find_all("h3", id="habitat")

    for habitat_header in habitat_headers:
        # Extract habitat text
        habitat_text = habitat_header.text.strip()

        # Find all ul elements directly following the habitat header
        ul_elements = habitat_header.find_next_siblings("ul")

        # Loop through each ul element (assuming multiple might exist)
        for ul_element in ul_elements:
            # Lists to store keywords and gloss data
            keywords = []
            gloss_texts = []

            # Loop through keywords-header elements within the current ul
            for keyword_element in ul_element.find_all("li", class_="keywords-header"):
                keywords.append(keyword_element.text.strip())

            # Loop through gloss elements within the current ul
            for gloss_link in ul_element.find_all("a", class_="gloss"):
                gloss_texts.append(gloss_link.text.strip())

            # Loop through span elements within the current ul
            for span_element in ul_element.find_all("span"):
                gloss_texts.append(span_element.text.strip())

            # Convert gloss_texts to a string representation
            gloss_texts_str = ', '.join(gloss_texts)

            # Create a dictionary for the current species and habitat
            species_data = {'Species Name': species_name, 'Habitat': habitat_text}

            # Add keywords and gloss texts to the dictionary
            for k in keywords:
                species_data[k] = gloss_texts_str

            # Append the data dictionary for the current species to the list
            data_list.append(species_data)

    # Find all h3 elements with id="food_habits"
    food_habit_headers = soup.find_all("h3", id="food_habits")

    for food_habit_header in food_habit_headers:
        # Extract food habit text
        food_habit_text = food_habit_header.text.strip()

        # Find all ul elements directly following the food habit header
        ul_elements = food_habit_header.find_next_siblings("ul")

        # Loop through each ul element (assuming multiple might exist)
        for ul_element in ul_elements:
            # Lists to store keywords and gloss data
            keywords = []
            gloss_texts = []

            # Loop through keywords-header elements within the current ul
            for keyword_element in ul_element.find_all("li", class_="keywords-header"):
                keywords.append(keyword_element.text.strip())

            # Loop through gloss elements within the current ul
            for gloss_link in ul_element.find_all("a", class_="gloss"):
                gloss_texts.append(gloss_link.text.strip())

            # Loop through span elements within the current ul
            for span_element in ul_element.find_all("span"):
                gloss_texts.append(span_element.text.strip())

            # Convert gloss_texts to a string representation
            gloss_texts_str = ', '.join(gloss_texts)

            # Update the data dictionary for the current species with food habits
            species_data['Food Habits'] = food_habit_text

            # Add keywords and gloss texts related to food habits to the dictionary
            for k in keywords:
                species_data[k] = gloss_texts_str

            # Append the updated data dictionary for the current species to the list
            data_list.append(species_data)

# Create a DataFrame from the collected data
df = pd.DataFrame(data_list)

# %%
df
# Out:
#                Species Name  Habitat        Habitat Regions  \
# 0        Loxodonta africana  Habitat  tropical, terrestrial
# 1        Loxodonta africana  Habitat                    NaN
# 2        Loxodonta africana  Habitat                    NaN
# 3        Loxodonta africana  Habitat                    NaN
# 4        Loxodonta africana  Habitat                    NaN
# ..                      ...      ...                    ...
# 372  Canis lupus familiaris  Habitat                    NaN
# 373  Canis lupus familiaris  Habitat                    NaN
# 374  Canis lupus familiaris  Habitat                    NaN
# 375  Canis lupus familiaris  Habitat                    NaN
# 376  Canis lupus familiaris  Habitat                    NaN
#
#                                     Terrestrial Biomes  Food Habits  \
# 0                                                  NaN          NaN
# 1    desert or dune, savanna or grassland, rainfore...          NaN
# ...

# %%
result_df = df = df.groupby('Species Name').agg(lambda x: ', '.join(y for y in x.dropna().unique()))
result_df
# Out:
#                        Habitat                          Habitat Regions  \
# Species Name
# Alces alces            Habitat                   temperate, terrestrial
# Antilocapra americana  Habitat                   temperate, terrestrial
# Antrozous pallidus     Habitat                   temperate, terrestrial
# Aplodontia rufa        Habitat                   temperate, terrestrial
# Bison bison            Habitat                   temperate, terrestrial
# ...                        ...                                      ...
# Ursus arctos           Habitat                   temperate, terrestrial
# Ursus maritimus        Habitat  polar, terrestrial, saltwater or marine
# Vicugna vicugna        Habitat                   temperate, terrestrial
# Vulpes lagopus         Habitat                       polar, terrestrial
# Zapus hudsonius        Habitat                   temperate, terrestrial
#
#                                                       Terrestrial Biomes  \
# ...

# %%
# end of experiment

# %%
df
# Out:
#                Species Name  Habitat                          Habitat Regions  \
# 0        Loxodonta africana  Habitat                    tropical, terrestrial
# 1        Loxodonta africana  Habitat                                      NaN
# 2        Loxodonta africana  Habitat                                      NaN
# 3                Ovis aries  Habitat                                      NaN
# 4                Bos taurus  Habitat         temperate, tropical, terrestrial
# ..                      ...      ...                                      ...
# 197             Canis lupus  Habitat                   temperate, terrestrial
# 198             Canis lupus  Habitat                                      NaN
# 199  Canis lupus familiaris  Habitat  temperate, tropical, polar, terrestrial
# 200  Canis lupus familiaris  Habitat                                      NaN
# 201  Canis lupus familiaris  Habitat                                      NaN
#
# ...

# %%
result_df = df = df.groupby('Species Name').agg(lambda x: ', '.join(y for y in x.dropna().unique()))
result_df
# Out:
#                        Habitat                          Habitat Regions  \
# Species Name
# Alces alces            Habitat                   temperate, terrestrial
# Antilocapra americana  Habitat                   temperate, terrestrial
# Antrozous pallidus     Habitat                   temperate, terrestrial
# Aplodontia rufa        Habitat                   temperate, terrestrial
# Bison bison            Habitat                   temperate, terrestrial
# ...                        ...                                      ...
# Ursus arctos           Habitat                   temperate, terrestrial
# Ursus maritimus        Habitat  polar, terrestrial, saltwater or marine
# Vicugna vicugna        Habitat                   temperate, terrestrial
# Vulpes lagopus         Habitat                       polar, terrestrial
# Zapus hudsonius        Habitat                   temperate, terrestrial
#
#                                                       Terrestrial Biomes  \
# ...

# %%
# test

# %%
import pandas as pd
species_names=("Loxodonta africana", "Ovis aries", "Bos taurus", "Alces alces", "Antilocapra americana", "Bison bison", "Odocoileus virginianus", "Oreamnos americanus", "Ovibos moschatus", "Ovis canadensis", "Dasypus novemcinctus", "Cervus canadensis", "Rangifer tarandus", "Antrozous pallidus", "Lasiurus blossevillii", "Leptonycteris curasoae", "Propithecus verreauxi", "Callithrix jacchus", "Daubentonia madagascariensis", "Sorex arcticus", "Enhydra lutris", "Lama glama", "Lama guanicoe", "Vicugna vicugna", "Vicugna pacos", "Homo sapiens", "Tarsius syrichta", "Mephitis mephitis", "Mustela spp.", "Taxidea taxus", "Neovison vison", "Lemur catta", "Galago senegalensis", "Nycticebus coucang", "Sapajus spp.", "Tayassuidae spp.", "Martes spp.", "Procyon lotor", "Nasua nasua", "Equus caballus", "Sus scrofa", "Sus scrofa", "Didelphis virginiana", "Mus musculus", "Ondatra zibethicus", "Oryzomys palustris", "Zapus hudsonius", "Castor canadensis", "Dipodomys ingens", "Erethizon dorsatum", "Geomys spp.", "Myocastor coypus", "Sciurus apache", "Aplodontia rufa", "Sciurus granatensis", "Tamias spp.", "Tamiasciurus hudsonicus", "Cynomys ludovicianus", "Marmota monax", "Ochotona princeps", "Oryctolagus cuniculus", "Lepus europaeus", "Lynx canadensis", "Panthera onca", "Felis catus", "Panthera leo", "Leopardus pardalis", "Vulpes lagopus", "Urocyon cinereoargenteus", "Canis latrans", "Ursus arctos", "Ursus maritimus", "Ursus arctos horribilis", "Ursus americanus", "Canis lupus", "Canis lupus familiaris")
# Define the column names
columns = ['Species Name', 'Habitat', 'Food Habits']

# Create an empty list to store the data
data = []

# Iterate over the species names
for species_name in species_names:
    # Format the URL with the species name
    url = f"https://animaldiversity.org/accounts/{species_name}"
    
    # Retrieve the HTML content
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Find the habitat headers
    habitat_headers = soup.find_all("h3", id="habitat")
    
    # Find the food habit headers
    food_habit_headers = soup.find_all("h3", id="food_habits")
    
    # Extract the habitat and food habits data
    habitat_data = []
    food_habit_data = []
    
    for habitat_header in habitat_headers:
        # Extract habitat text
        habitat_text = habitat_header.text.strip()
        
        # Find all ul elements directly following the habitat header
        ul_elements = habitat_header.find_next_siblings("ul")
        
        # Loop through each ul element
        for ul_element in ul_elements:
            # Loop through keywords-header elements within the current ul
            for keyword_element in ul_element.find_all("li", class_="keywords-header"):
                habitat_data.append(keyword_element.text.strip())
            
            # Loop through gloss elements within the current ul
            for gloss_link in ul_element.find_all("a", class_="gloss"):
                habitat_data.append(gloss_link.text.strip())
            
            # Loop through span elements within the current ul
            for span_element in ul_element.find_all("span"):
                habitat_data.append(span_element.text.strip())
    
    for food_habit_header in food_habit_headers:
        # Extract food habit text
        food_habit_text = food_habit_header.text.strip()
        
        # Find all ul elements directly following the food habit header
        ul_elements = food_habit_header.find_next_siblings("ul")
        
        # Loop through each ul element
        for ul_element in ul_elements:
            # Loop through keywords-header elements within the current ul
            for keyword_element in ul_element.find_all("li", class_="keywords-header"):
                food_habit_data.append(keyword_element.text.strip())
            
            # Loop through gloss elements within the current ul
            for gloss_link in ul_element.find_all("a", class_="gloss"):
                food_habit_data.append(gloss_link.text.strip())
            
            # Loop through span elements within the current ul
            for span_element in ul_element.find_all("span"):
                food_habit_data.append(span_element.text.strip())
    
    # Append the data to the list
    data.append([species_name, habitat_data, food_habit_data])

# Create the dataframe
df = pd.DataFrame(data, columns=columns)

# %%
df
# Out:
#                Species Name  \
# 0        Loxodonta africana
# 1                Ovis aries
# 2                Bos taurus
# 3               Alces alces
# 4     Antilocapra americana
# ..                      ...
# 71          Ursus maritimus
# 72  Ursus arctos horribilis
# 73         Ursus americanus
# 74              Canis lupus
# 75   Canis lupus familiaris
#
#                                               Habitat  \
# 0   [Habitat Regions, tropical, terrestrial, Terre...
# 1   [Terrestrial Biomes, desert or dune, savanna o...
# 2   [Habitat Regions, temperate, tropical, terrest...
# 3   [Habitat Regions, temperate, terrestrial, Terr...
# 4   [Habitat Regions, temperate, terrestrial, Terr...
# ..                                                ...
# 71  [Habitat Regions, polar, terrestrial, saltwate...
# 72                                                 []
# 73  [Habitat Regions, temperate, terrestrial, Terr...
# 74  [Habitat Regions, temperate, terrestrial, Terr...
# ...
