# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('teeth_characteristics.csv')
df.head()
# Out:
#          Order        Family             Species   Dental formula
# 0  Insectivora     Soricidae       Sorex anereus  3.1.3.3/1.1.1.3
# 1  Insectivora      Talpidae  Condylura cristata  3.1.4.3/3.1.4.3
# 2  Insectivora      Talpidae  Scalopus aquaticus  3.1.3.3/2.0.3.3
# 3      Primata  Notharctidae  Cantius frugivorus  2.1.4.3/2.1.4.3
# 4      Primata  Notharctidae  Europolemur klatti  2.1.3.3/2.1.3.3

# %%
# Split the values in the "dental formula" column and assign them to new columns
df[['IM', 'CM', 'PM', 'MM', 'Im', 'Cm', 'pM', 'Mm']] = df['Dental formula'].str.split('[./]', expand=True)

df
# Out:
#            Order         Family                      Species   Dental formula  \
# 0    Insectivora      Soricidae                Sorex anereus  3.1.3.3/1.1.1.3
# 1    Insectivora       Talpidae           Condylura cristata  3.1.4.3/3.1.4.3
# 2    Insectivora       Talpidae           Scalopus aquaticus  3.1.3.3/2.0.3.3
# 3        Primata   Notharctidae           Cantius frugivorus  2.1.4.3/2.1.4.3
# 4        Primata   Notharctidae           Europolemur klatti  2.1.3.3/2.1.3.3
# 5        Primata       Adapidae           Adapis parisiensis  2.1.4.3/2.1.4.3
# 6        Primata    Megalapidae         Megalodopis edwardsi  0.1.3.3/2.1.3.3
# 7        Primata       Idriidae  Mesopropithecus pithecoides  2.1.2.3/2.0.2.3
# 8        Primata  Daubentonidae  Daubentonia magadascarensis  1.0.1.3/1.0.0.3
# 9        Primata   Paraptecidae               Qatrania wingi  2.1.3.3/2.1.3.3
# 10       Primata   Paraptecidae        Parapithecus grangeri  2.1.3.3/0.1.3.3
# 11       Primata        Cebidae                 Cebus apella  2.1.3.3/2.1.3.3
# 12       Primata       Pongidae              Pan troglodytes  2.1.2.3/2.1.2.3
# 13     Carnivora        Canidae                 Vulpes vulva  3.1.4.2/3.1.4.3
# 14     Carnivora     Mustelidae              Mustela nivalis  3.1.3.1/3.1.3.2
# 15     Carnivora        Felidae                   Felis linx  3.1.2.1/3.1.2.1
# 16     Carnivora        Felidae               Felis concolor  3.1.3.1/3.1.2.1
# 17     Carnivora        Ursidae       Ailuropoda melanoleuca  3.1.4.2/3.1.4.3
# 18     Carnivora        Ursidae             Ursus americanus  3.1.4.2/3.1.4.3
# 19  Artiodactyla          Suina                   Sus scrofa  3.1.4.3/3.1.4.3
# 20  Artiodactyla        Bovidae              Ovis canadensis  0.0.3.3/3.1.3.3
# 21  Artiodactyla      Camelidae          Camelus dromedarius  1.1.3.3/3.1.2.3
# 22  Artiodactyla      Camelidae                   Lama glama  1.1.3.3/3.1.3.3
# 23  Artiodactyla       Cervidae                   Cervus spp  0.1.3.3/3.1.3.3
# 24      Rodentia      Sciuridae                Marmota monax  1.0.2.3/1.0.1.3
# 25      Rodentia      Sciuridae              Tamias striatus  1.0.1.3/1.0.1.3
# 26      Rodentia        Muridae                Rattus rattus  1.0.0.3/1.0.0.3
# 27      Rodentia      Zapodidae              Zapus hudsonius  1.0.1.3/1.0.0.3
#
#    IM CM PM MM Im Cm pM Mm
# 0   3  1  3  3  1  1  1  3
# 1   3  1  4  3  3  1  4  3
# 2   3  1  3  3  2  0  3  3
# 3   2  1  4  3  2  1  4  3
# 4   2  1  3  3  2  1  3  3
# 5   2  1  4  3  2  1  4  3
# 6   0  1  3  3  2  1  3  3
# 7   2  1  2  3  2  0  2  3
# 8   1  0  1  3  1  0  0  3
# 9   2  1  3  3  2  1  3  3
# 10  2  1  3  3  0  1  3  3
# 11  2  1  3  3  2  1  3  3
# 12  2  1  2  3  2  1  2  3
# 13  3  1  4  2  3  1  4  3
# 14  3  1  3  1  3  1  3  2
# 15  3  1  2  1  3  1  2  1
# 16  3  1  3  1  3  1  2  1
# 17  3  1  4  2  3  1  4  3
# 18  3  1  4  2  3  1  4  3
# 19  3  1  4  3  3  1  4  3
# 20  0  0  3  3  3  1  3  3
# 21  1  1  3  3  3  1  2  3
# 22  1  1  3  3  3  1  3  3
# 23  0  1  3  3  3  1  3  3
# 24  1  0  2  3  1  0  1  3
# 25  1  0  1  3  1  0  1  3
# 26  1  0  0  3  1  0  0  3
# 27  1  0  1  3  1  0  0  3

# %%
species_names = df['Species'].tolist()
species_names
# Out:
# ['Sorex anereus',
#  'Condylura cristata',
#  'Scalopus aquaticus',
#  'Cantius frugivorus',
#  'Europolemur klatti',
#  'Adapis parisiensis',
#  'Megalodopis edwardsi',
#  'Mesopropithecus pithecoides',
#  'Daubentonia magadascarensis',
#  'Qatrania wingi',
#  'Parapithecus grangeri',
#  'Cebus apella',
#  'Pan troglodytes',
#  'Vulpes vulva',
#  'Mustela nivalis',
#  'Felis linx',
#  'Felis concolor',
#  'Ailuropoda melanoleuca',
#  'Ursus americanus',
#  'Sus scrofa',
#  'Ovis canadensis',
#  'Camelus dromedarius',
#  'Lama glama',
#  'Cervus spp',
#  'Marmota monax',
#  'Tamias striatus',
#  'Rattus rattus',
#  'Zapus hudsonius']

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Initialize a list to store data dictionaries for each species
data_list = []

# Assuming 'species_names' is a list of species names
for species_name in species_names:
    # Format the URL with the species name
    url = f"https://animaldiversity.org/accounts/{species_name}"

    # Retrieve the HTML content
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    # Find all h3 elements with id="habitat"
    habitat_headers = soup.find_all("h3", id="habitat")

    for habitat_header in habitat_headers:
        # Extract habitat text
        habitat_text = habitat_header.text.strip()

        # Find all ul elements directly following the habitat header
        ul_elements = habitat_header.find_next_siblings("ul")

        # Loop through each ul element (assuming multiple might exist)
        for ul_element in ul_elements:
            # Lists to store keywords and gloss data
            keywords = []
            gloss_texts = []

            # Loop through keywords-header elements within the current ul
            for keyword_element in ul_element.find_all("li", class_="keywords-header"):
                keywords.append(keyword_element.text.strip())

            # Loop through gloss elements within the current ul
            for gloss_link in ul_element.find_all("a", class_="gloss"):
                gloss_texts.append(gloss_link.text.strip())

            # Loop through span elements within the current ul
            for span_element in ul_element.find_all("span"):
                gloss_texts.append(span_element.text.strip())

            # Convert gloss_texts to a string representation
            gloss_texts_str = ', '.join(gloss_texts)

            # Create a dictionary for the current species and habitat
            species_data = {'Species Name': species_name, 'Habitat': habitat_text}

            # Add keywords and gloss texts to the dictionary
            for k in keywords:
                species_data[k] = gloss_texts_str

            # Append the data dictionary for the current species to the list
            data_list.append(species_data)

    # Find all h3 elements with id="food_habits"
    food_habit_headers = soup.find_all("h3", id="food_habits")

    for food_habit_header in food_habit_headers:
        # Extract food habit text
        food_habit_text = food_habit_header.text.strip()

        # Find all ul elements directly following the food habit header
        ul_elements = food_habit_header.find_next_siblings("ul")

        # Loop through each ul element (assuming multiple might exist)
        for ul_element in ul_elements:
            # Lists to store keywords and gloss data
            keywords = []
            gloss_texts = []

            # Loop through keywords-header elements within the current ul
            for keyword_element in ul_element.find_all("li", class_="keywords-header"):
                keywords.append(keyword_element.text.strip())

            # Loop through gloss elements within the current ul
            for gloss_link in ul_element.find_all("a", class_="gloss"):
                gloss_texts.append(gloss_link.text.strip())

            # Loop through span elements within the current ul
            for span_element in ul_element.find_all("span"):
                gloss_texts.append(span_element.text.strip())

            # Convert gloss_texts to a string representation
            gloss_texts_str = ', '.join(gloss_texts)

            # Update the data dictionary for the current species with food habits
            species_data['Food Habits'] = food_habit_text

            # Add keywords and gloss texts related to food habits to the dictionary
            for k in keywords:
                species_data[k] = gloss_texts_str

            # Append the updated data dictionary for the current species to the list
            data_list.append(species_data)

# Create a DataFrame from the collected data
df = pd.DataFrame(data_list)

# %%
result_df = df = df.groupby('Species Name').agg(lambda x: ', '.join(y for y in x.dropna().unique()))
result_df
# Out:
#                         Habitat                     Habitat Regions  \
# Species Name
# Ailuropoda melanoleuca  Habitat                           temperate
# Camelus dromedarius     Habitat              temperate, terrestrial
# Cebus apella            Habitat               tropical, terrestrial
# Condylura cristata      Habitat  temperate, terrestrial, freshwater
# Lama glama              Habitat              temperate, terrestrial
# Marmota monax           Habitat              temperate, terrestrial
# Mustela nivalis         Habitat                           temperate
# Ovis canadensis         Habitat              temperate, terrestrial
# Pan troglodytes         Habitat               tropical, terrestrial
# Rattus rattus           Habitat    temperate, tropical, terrestrial
# Scalopus aquaticus      Habitat              temperate, terrestrial
# Sus scrofa              Habitat              temperate, terrestrial
# Tamias striatus         Habitat
# Ursus americanus        Habitat              temperate, terrestrial
# Zapus hudsonius         Habitat              temperate, terrestrial
#
#                                                        Terrestrial Biomes  \
# Species Name
# Ailuropoda melanoleuca                                             forest
# Camelus dromedarius                  desert or dune, savanna or grassland
# Cebus apella                                forest, rainforest, mountains
# Condylura cristata                                          taiga, forest
# Lama glama                                                      mountains
# Marmota monax                                savanna or grassland, forest
# Mustela nivalis         tundra, taiga, savanna or grassland, forest, r...
# Ovis canadensis                      desert or dune, chaparral, mountains
# Pan troglodytes         savanna or grassland, chaparral, forest, rainf...
# Rattus rattus           savanna or grassland, chaparral, forest, rainf...
# Scalopus aquaticus                                                 forest
# Sus scrofa                                   savanna or grassland, forest
# Tamias striatus                                                    forest
# Ursus americanus                                     forest, scrub forest
# Zapus hudsonius                           savanna or grassland, mountains
#
#                                              Aquatic Biomes  \
# Species Name
# Ailuropoda melanoleuca
# Camelus dromedarius
# Cebus apella
# Condylura cristata      lakes and ponds, rivers and streams
# Lama glama
# Marmota monax
# Mustela nivalis
# Ovis canadensis
# Pan troglodytes
# Rattus rattus
# Scalopus aquaticus
# Sus scrofa
# Tamias striatus
# Ursus americanus
# Zapus hudsonius
#
#                                  Wetlands            Other Habitat Features  \
# Species Name
# Ailuropoda melanoleuca
# Camelus dromedarius
# Cebus apella
# Condylura cristata      marsh, swamp, bog                          riparian
# Lama glama                                                     agricultural
# Marmota monax                              suburban, agricultural, riparian
# Mustela nivalis                                                agricultural
# Ovis canadensis
# Pan troglodytes
# Rattus rattus                                 urban, suburban, agricultural
# Scalopus aquaticus                                                 suburban
# Sus scrofa                   marsh, swamp            agricultural, riparian
# Tamias striatus                               urban, suburban, agricultural
# Ursus americanus                                                   riparian
# Zapus hudsonius                     marsh                          riparian
#
#                         Food Habits  \
# Species Name
# Ailuropoda melanoleuca  Food Habits
# Camelus dromedarius     Food Habits
# Cebus apella            Food Habits
# Condylura cristata      Food Habits
# Lama glama              Food Habits
# Marmota monax           Food Habits
# Mustela nivalis         Food Habits
# Ovis canadensis         Food Habits
# Pan troglodytes         Food Habits
# Rattus rattus           Food Habits
# Scalopus aquaticus      Food Habits
# Sus scrofa              Food Habits
# Tamias striatus         Food Habits
# Ursus americanus        Food Habits
# Zapus hudsonius         Food Habits
#
#                                                              Primary Diet  \
# Species Name
# Ailuropoda melanoleuca                                herbivore, folivore
# Camelus dromedarius                                   herbivore, folivore
# Cebus apella                                                     omnivore
# Condylura cristata                                   carnivore, vermivore
# Lama glama                                            herbivore, folivore
# Marmota monax                                         herbivore, folivore
# Mustela nivalis         carnivore, piscivore, insectivore, scavenger, ...
# Ovis canadensis                                       herbivore, folivore
# Pan troglodytes                                                  omnivore
# Rattus rattus                                        herbivore, granivore
# Scalopus aquaticus                      carnivore, insectivore, vermivore
# Sus scrofa                                                       omnivore
# Tamias striatus                            herbivore, granivore, omnivore
# Ursus americanus                                                 omnivore
# Zapus hudsonius                                      herbivore, granivore
#
#                                                              Animal Foods  \
# Species Name
# Ailuropoda melanoleuca                             mammals, fish, insects
# Camelus dromedarius
# Cebus apella            carrion, birds, mammals, amphibians, reptiles,...
# Condylura cristata      fish, insects, mollusks, terrestrial worms, aq...
# Lama glama
# Marmota monax                                     eggs, insects, mollusks
# Mustela nivalis         carrion, birds, mammals, amphibians, reptiles,...
# Ovis canadensis
# Pan troglodytes                   birds, mammals, reptiles, eggs, insects
# Rattus rattus                                                     insects
# Scalopus aquaticus                             insects, terrestrial worms
# Sus scrofa              carrion, birds, mammals, amphibians, reptiles,...
# Tamias striatus                          eggs, insects, terrestrial worms
# Ursus americanus                                         carrion, insects
# Zapus hudsonius                                                   insects
#
#                                                               Plant Foods  \
# Species Name
# Ailuropoda melanoleuca                                      leaves, fruit
# Camelus dromedarius                                                leaves
# Cebus apella            leaves, roots and tubers, wood, bark, or stems...
# Condylura cristata
# Lama glama              leaves, roots and tubers, seeds, grains, and n...
# Marmota monax           leaves, wood, bark, or stems, seeds, grains, a...
# Mustela nivalis
# Ovis canadensis                                                    leaves
# Pan troglodytes         leaves, wood, bark, or stems, seeds, grains, a...
# Rattus rattus           leaves, wood, bark, or stems, seeds, grains, a...
# Scalopus aquaticus                                seeds, grains, and nuts
# Sus scrofa               roots and tubers, seeds, grains, and nuts, fruit
# Tamias striatus                            seeds, grains, and nuts, fruit
# Ursus americanus         roots and tubers, seeds, grains, and nuts, fruit
# Zapus hudsonius                    leaves, seeds, grains, and nuts, fruit
#
#                             Foraging Behavior Other Foods
# Species Name
# Ailuropoda melanoleuca
# Camelus dromedarius
# Cebus apella
# Condylura cristata
# Lama glama
# Marmota monax
# Mustela nivalis         stores or caches food
# Ovis canadensis
# Pan troglodytes
# Rattus rattus
# Scalopus aquaticus
# Sus scrofa
# Tamias striatus         stores or caches food      fungus
# Ursus americanus
# Zapus hudsonius                                    fungus
